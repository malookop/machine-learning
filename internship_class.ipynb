# %% [markdown]
# my first notebook

# %% [markdown]
# *italicized text*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
titanic=pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.csv")

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# #data analytics
# step 1--import library
# step2-import/read data

# %%
salary=pd.read_csv("https://github.com/ybifoundation/Dataset/raw/main/Salary%20Data.csv")

# %%
salary.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
salary.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
salary.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
salary.shape
# Out:
# (40, 2)

# %% [markdown]
# step3---define target (y) and feature(x)

# %% [markdown]
# there are two columns

# %% [markdown]
#         y           x
# case1--exp       salary
# case2---salary     exp
#
# case 1 is not possible because there is no relation between salary to exp
# it show no error but it wrong
# u have to decide what criteria can be depandant and independent

# %% [markdown]
# syntax for defining dependent and independent variable

# %%
y=salary["Salary"]
x=salary[['Experience Years']]

# %%
salary.shape
# Out:
# (40, 2)

# %%
x.shape
# Out:
# (40, 1)

# %%
y.shape
# Out:
# (40,)

# %% [markdown]
# x is a column vector and y is a flat vector

# %%
len(x)
# Out:
# 40

# %% [markdown]
# step4---train test split

# %% [markdown]
# sklearn library is used

# %% [markdown]
# syntax for importing ;
# from sklearn.model import function

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# train size for adjusting size between training and testing

# %% [markdown]
# x_train give random value because it best if value change

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y)
X_train
# Out:
#     Experience Years
# 12               3.7
# 7                2.9
# 36               9.5
# 20               4.7
# 10               3.2
# 28               6.5
# 13               3.8
# 4                2.0
# 23               5.3
# 24               5.5
# 16               4.0
# 27               6.2
# 21               4.9
# 5                2.2
# 38              10.3
# 9                3.2
# 11               3.5
# 15               4.0
# 6                2.5
# 31               7.9
# 39              10.5
# 37               9.6
# 14               3.9
# 3                1.5
# 25               5.9
# 34               8.7
# 29               6.8
# 1                1.2
# 2                1.3
# 18               4.3

# %%
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((30, 1), (10, 1), (30,), (10,))

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,train_size=0.7,random_state=2529)
X_train
# Out:
#     Experience Years
# 28               6.5
# 31               7.9
# 34               8.7
# 20               4.7
# 4                2.0
# 3                1.5
# 18               4.3
# 26               6.0
# 2                1.3
# 22               5.1
# 35               9.0
# 7                2.9
# 39              10.5
# 30               7.1
# 10               3.2
# 0                1.1
# 9                3.2
# 13               3.8
# 5                2.2
# 37               9.6
# 23               5.3
# 25               5.9
# 21               4.9
# 24               5.5
# 8                3.0
# 36               9.5
# 15               4.0
# 32               8.2

# %%
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((28, 1), (12, 1), (28,), (12,))

# %% [markdown]
# step5----select model

# %% [markdown]
# using linear regression method

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %% [markdown]
# step6---train model(fit model)
# from here machine learning starts

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# y=c+mx
#
# c=?,m=?
# model of reggression
# salary=26596+9405exp+e

# %%
model.intercept_
# Out:
# 26596.961311068262

# %%
model.coef_
# Out:
# array([9405.61663234])

# %% [markdown]
# step7----prediction

# %% [markdown]
# give independent argument to predict dependent argument

# %%
Y_pred=model.predict(X_test)

# %% [markdown]
# salary=26596.9+9405.6exp
# =26596.9+9405.6*6.5
# =

# %% [markdown]
# step 8:accuracy of model

# %% [markdown]
# y act     y pred    error   |e|      e^2
# 20         21         -1     |1|    (-1)^2
# 20         19          1     |1|    (1)^2
# 22         24         -2     |2|    (-2)^2
#
#
#  mean-----           sumation|e|  sum(e)^2
#                             ----  --------
#                               3      3
#
#
#           either mean absolute percentage error (e^2%)

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mean_absolute_percentage_error(Y_test,Y_pred)
# Out:
# 0.06384602996141632

# %% [markdown]
# 6%=error
# accuracy=100-6=94%

# %% [markdown]
# #problem house price selection

# %% [markdown]
# step 1

# %%
import pandas as pd

# %% [markdown]
# step 2

# %%
house=pd.read_csv("https://github.com/ybifoundation/Dataset/raw/main/Boston.csv")

# %%
house.head()

# %% [markdown]
# medv=y
# all others(13)=x

# %% [markdown]
# step 3

# %%
house.columns

# %%
y=house["MEDV"]
X=house[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']]

# %% [markdown]
# step 4

# %%
X.shape,y.shape
# Out:
# ((506, 13), (506,))

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=2529)

# %% [markdown]
# step 5

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %% [markdown]
# step 6

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 31.25533453751924

# %%
model.coef_
# Out:
# array([-1.27113473e-01,  3.42913377e-02,  2.60868350e-03,  2.38959719e+00,
#        -1.82552392e+01,  4.48454125e+00,  1.61769130e-03, -1.46612188e+00,
#         2.40205715e-01, -9.08110896e-03, -9.17943140e-01,  1.03133823e-02,
#        -5.29465536e-01])

# %% [markdown]
# housee=31.25-1.23X1+3.4X2+2.6X3----------

# %% [markdown]
# step 7

# %%
y_pred=model.predict(X_test)

# %% [markdown]
# step 8

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.1702803409644982

# %% [markdown]
# error =17%
# acccuracy=100-17=83%

# %% [markdown]
# #for classification problem

# %% [markdown]
# step 1--import library

# %%
import pandas as pd

# %% [markdown]
# step 2--import/read data

# %%
diabetes=pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/Diabetes.csv")

# %%
diabetes.head()

# %%
diabetes.info()

# %%
diabetes.describe()

# %% [markdown]
# step 3--define x and y

# %%
diabetes.columns
# Out:
# Index(['pregnancies', 'glucose', 'diastolic', 'triceps', 'insulin', 'bmi',
#        'dpf', 'age', 'diabetes'],
#       dtype='object')

# %%
y=diabetes["diabetes"]
X=diabetes[['pregnancies', 'glucose', 'diastolic', 'triceps', 'insulin', 'bmi',
       'dpf', 'age']]

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# step 4---tain test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=2529)

# %% [markdown]
# can not usee linear regression function
# go copy

# %%
#step 5--select a model
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(max_iter=500)

# %% [markdown]
# default iter is 100

# %% [markdown]
# logit=    1
#        ---------
#        1+e^-z
#
# z is (y=b0+b1x1+b2x2------------)

# %%
#step 6--train model
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
#step 7--
y_pred=model.predict(X_test)

# %%
#step 8 accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7760416666666666

# %% [markdown]
# here not use mean absolute error but use accuracy error

# %% [markdown]
# acuracy is straight forward here u do not have to cal it from 100-77
# it simply given directly

# %% [markdown]
# yact     ypred
# 0         0
# 1         1
# 0         1     wrong
# 1         0    wrong
#
# accuracy=no of correct        2
#         --------------    = -----=50%
#         total no of pred      4

# %% [markdown]
# #using knn

# %%
#step 1
import pandas as pd

# %%
#step 2
diabetes=pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/Diabetes.csv")

# %%
#step 3
y=diabetes['diabetes']
X=diabetes[['pregnancies', 'triceps', 'glucose', 'diastolic','insulin', 'bmi',
       'dpf', 'age']]

# %%
#step 4
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=2529)

# %%
#step 5
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()

# %%
#step6
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
#step 7
y_pred=model.predict(X_test)

# %%
#step 8
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
accuracy_score(y_test,y_pred)
# Out:
# 0.6770833333333334

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[98, 20],
#        [42, 32]])

# %%
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.70      0.83      0.76       118\n           1       0.62      0.43      0.51        74\n\n    accuracy                           0.68       192\n   macro avg       0.66      0.63      0.63       192\nweighted avg       0.67      0.68      0.66       192\n'

# %% [markdown]
# confusion_matrix(y_test,y_pred)
# array([[133,  12],
#        [ 41,  45]])

# %% [markdown]
# accuracy_score(y_test,y_pred)
# 0.7705627705627706

# %% [markdown]
# print(classification_report(y_test,y_pred))
#               precision    recall  f1-score   support
#
#            0       0.76      0.92      0.83       145
#            1       0.79      0.52      0.63        86
#
#     accuracy                           0.77       231
#    macro avg       0.78      0.72      0.73       231
# weighted avg       0.77      0.77      0.76       231

# %% [markdown]
# #chances of admisssion prediction

# %%
#step 1
import pandas as pd

# %%
#step 2
admission=pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/Admission%20Chance.csv")

# %%
admission.head()
# Out:
#    Serial No  GRE Score  TOEFL Score  University Rating   SOP  LOR   CGPA  \
# 0          1        337          118                  4   4.5   4.5  9.65
# 1          2        324          107                  4   4.0   4.5  8.87
# 2          3        316          104                  3   3.0   3.5  8.00
# 3          4        322          110                  3   3.5   2.5  8.67
# 4          5        314          103                  2   2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
admission.describe()
# Out:
#         Serial No   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
admission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No          400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4    SOP               400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
admission.columns
# Out:
# Index(['Serial No', 'GRE Score', 'TOEFL Score', 'University Rating', ' SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
#step 3
y=admission['Chance of Admit ']
X=admission[['Serial No', 'GRE Score', 'TOEFL Score', 'University Rating', ' SOP',
       'LOR ', 'CGPA', 'Research']]

# %%
admission.shape
# Out:
# (400, 9)

# %%
#step 4
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=2529)
X_train.shape
# Out:
# (300, 8)

# %%
#step 5
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
#or step 5
from sklearn.neighbors import KNeighborsRegressor
model=KNeighborsRegressor()

# %%
#step 6
model.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
model.intercept_

# %%
model.coef_
# Out:
# array([ 0.00017307,  0.00196337,  0.00422169,  0.00739279, -0.00103725,
#         0.02017428,  0.09670386,  0.02178675])

# %% [markdown]
# model=-1.313+0.00017307x1+0.00196337x2

# %%
#step 7
y_pred=model.predict(X_test)

# %%
#step 8
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.007095240000000002

# %%
mean_absolute_error(y_pred,y_test)
# Out:
# 0.06206000000000001

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.10239044027420739

# %% [markdown]
#  linear regression---100-7=93
#  KNeighbors----100-10=90

# %% [markdown]
# #ice cream sales revenue

# %%
#1
import pandas as pd

# %%
#2
icecream=pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/Ice%20Cream.csv")

# %%
icecream.head()
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317

# %%
icecream.columns
# Out:
# Index(['Temperature', 'Revenue'], dtype='object')

# %%
#3
X=icecream[['Temperature']]
y=icecream['Revenue']

# %%
#4
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.7,random_state=2529)

# %%
#5
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
from sklearn.neighbors import KNeighborsRegressor
model=KNeighborsRegressor()

# %%
#6
model.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
#7
y_pred=model.predict(X_test)

# %%
#8
from  sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error

# %%
mean_absolute_error(y_pred,y_test)
# Out:
# 20.84

# %%
mean_absolute_percentage_error(y_pred,y_test)
# Out:
# 0.04746800875645092

# %%
mean_squared_error(y_pred,y_test)
# Out:
# 685.5530666666666

# %% [markdown]
# #error
# linear reg---100-4=96
# KNeighborrs---100-4.5=95.5

# %% [markdown]
# #cancer prediction

# %%
#1
import pandas as pd

# %%
#2
cancer=pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Cancer.csv')

# %%
cancer.head(100)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     842302         M       17.990         10.38          122.80     1001.0
# 1     842517         M       20.570         17.77          132.90     1326.0
# 2   84300903         M       19.690         21.25          130.00     1203.0
# 3   84348301         M       11.420         20.38           77.58      386.1
# 4   84358402         M       20.290         14.34          135.10     1297.0
# ..       ...       ...          ...           ...             ...        ...
# 95     86208         M       20.260         23.03          132.40     1264.0
# 96     86211         B       12.180         17.84           77.79      451.1
# 97    862261         B        9.787         19.94           62.11      294.5
# 98    862485         B       11.600         12.84           74.34      412.6
# 99    862548         M       14.420         19.77           94.48      642.5
#
# ...

# %%
cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
cancer.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
cancer.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
#3
y=cancer["diagnosis"]
X=cancer.drop(["id",'diagnosis','Unnamed: 32'],axis=1)

# %%
#4
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.6,random_state=2529)

# %%
#5
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
#or 5
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
y_train.shape
# Out:
# (341,)

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
#6
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#7
y_pred=model.predict(X_test)

# %%
#8
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9473684210526315

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[134,  10],
#        [  2,  82]])

# %%
classification_report(y_pred,y_test)
# Out:
# '              precision    recall  f1-score   support\n\n           B       0.99      0.93      0.96       144\n           M       0.89      0.98      0.93        84\n\n    accuracy                           0.95       228\n   macro avg       0.94      0.95      0.94       228\nweighted avg       0.95      0.95      0.95       228\n'

# %% [markdown]
# #fish weight prediction

# %%
#1
import pandas as pd

# %%
#2
fish=pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/Fish.csv")

# %%
fish.tail(10)
# Out:
#      Category Species  Weight  Height   Width  Length1  Length2  Length3
# 149         6   Smelt     9.8  2.0832  1.2772     10.7     11.2     12.4
# 150         6   Smelt     8.7  1.9782  1.2852     10.8     11.3     12.6
# 151         6   Smelt    10.0  2.2139  1.2838     11.3     11.8     13.1
# 152         6   Smelt     9.9  2.2139  1.1659     11.3     11.8     13.1
# 153         6   Smelt     9.8  2.2044  1.1484     11.4     12.0     13.2
# 154         6   Smelt    12.2  2.0904  1.3936     11.5     12.2     13.4
# 155         6   Smelt    13.4  2.4300  1.2690     11.7     12.4     13.5
# 156         6   Smelt    12.2  2.2770  1.2558     12.1     13.0     13.8
# 157         6   Smelt    19.7  2.8728  2.0672     13.2     14.3     15.2
# 158         6   Smelt    19.9  2.9322  1.8792     13.8     15.0     16.2

# %%
fish.columns
# Out:
# Index(['Category', 'Species', 'Weight', 'Height', 'Width', 'Length1',
#        'Length2', 'Length3'],
#       dtype='object')

# %%
fish.info()

# %%
fish.describe()

# %%
#3
y=fish['Weight']
X=fish.drop(['Species', 'Weight'],axis=1)

# %%
X.shape,y.shape
# Out:
# ((159, 6), (159,))

# %%
type(X),type(y)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
#4
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=2529,train_size=0.7)

# %%
#5
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
#0r 5
from sklearn.neighbors import KNeighborsRegressor
model=KNeighborsRegressor()

# %%
#6
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_train.shape,X_test.shape,y_test.shape,y_train.shape
# Out:
# ((111, 6), (48, 6), (48,), (111,))

# %%
#7
y_pred=model.predict(X_test)

# %%
#8
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error,r2_score

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 15909.606036005664

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 99.58910366731813

# %%
mean_absolute_percentage_error(y_pred,y_test)
# Out:
# 0.3555448148657467

# %%
r2_score(y_test,y_pred)
# Out:
# 0.83982461599445

# %% [markdown]
# ##purchase prediction and effect of Micro-numerocity

# %%
#1
import pandas as pd

# %%
#2
purchase=pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Customer%20Purchase.csv')

# %%
purchase.head()
# Out:
#    Customer ID  Age  Gender Education   Review Purchased
# 0         1021   30  Female    School  Average        No
# 1         1022   68  Female        UG     Poor        No
# 2         1023   70  Female        PG     Good        No
# 3         1024   72  Female        PG     Good        No
# 4         1025   16  Female        UG  Average        No

# %%
purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer ID  50 non-null     int64
#  1   Age          50 non-null     int64
#  2   Gender       50 non-null     object
#  3   Education    50 non-null     object
#  4   Review       50 non-null     object
#  5   Purchased    50 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 2.5+ KB

# %%
purchase.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Education', 'Review', 'Purchased'], dtype='object')

# %%
#3
y=purchase['Purchased']
X=purchase.drop(['Purchased','Customer ID'],axis=1)

# %%
#encoding categorical variable
X.replace({"Review":{"Poor":0,"Average":1,"Good":2}},inplace=True)
X.replace({"Education":{"School":0,"UG":1,"PG":2}},inplace=True)
X.replace({"Gender":{"Male":0,"Female":1}},inplace=True)

# %%
X.head(10)
# Out:
#    Age  Gender  Education  Review
# 0   30       1          0       1
# 1   68       1          1       0
# 2   70       1          2       2
# 3   72       1          2       2
# 4   16       1          1       1
# 5   31       1          0       1
# 6   18       0          0       2
# 7   60       1          0       0
# 8   65       1          1       1
# 9   74       0          1       2

# %% [markdown]
# inplace=True  means the data will be modified without returning a copy of the data or original data

# %%
#4
from sklearn.model_selection import train_test_split
X_test,X_train,y_test,y_train=train_test_split(X,y,train_size=0.7,random_state=2529)

# %%
#5
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()

# %%
#or5
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
#or5
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()

# %%
#6
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
#7
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array(['Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No',
#        'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes'], dtype=object)

# %%
#8
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 3, 16],
#        [ 2, 14]])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.4857142857142857

# %%
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n          No       0.60      0.16      0.25        19\n         Yes       0.47      0.88      0.61        16\n\n    accuracy                           0.49        35\n   macro avg       0.53      0.52      0.43        35\nweighted avg       0.54      0.49      0.41        35\n'

# %% [markdown]
# #credit card default prediction

# %%
#1
import pandas as pd

# %%
#2
default=pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Credit%20Default.csv')

# %%
default.head()
# Out:
#         Income        Age         Loan  Loan to Income  Default
# 0  66155.92510  59.017015  8106.532131        0.122537        0
# 1  34415.15397  48.117153  6564.745018        0.190752        0
# 2  57317.17006  63.108049  8020.953296        0.139940        0
# 3  42709.53420  45.751972  6103.642260        0.142911        0
# 4  66952.68885  18.584336  8770.099235        0.130990        1

# %%
default.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Income          2000 non-null   float64
#  1   Age             2000 non-null   float64
#  2   Loan            2000 non-null   float64
#  3   Loan to Income  2000 non-null   float64
#  4   Default         2000 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 78.2 KB

# %%
default.describe()
# Out:
#              Income          Age          Loan  Loan to Income      Default
# count   2000.000000  2000.000000   2000.000000     2000.000000  2000.000000
# mean   45331.600018    40.927143   4444.369695        0.098403     0.141500
# std    14326.327119    13.262450   3045.410024        0.057620     0.348624
# min    20014.489470    18.055189      1.377630        0.000049     0.000000
# 25%    32796.459720    29.062492   1939.708847        0.047903     0.000000
# 50%    45789.117310    41.382673   3974.719418        0.099437     0.000000
# 75%    57791.281670    52.596993   6432.410625        0.147585     0.000000
# max    69995.685580    63.971796  13766.051240        0.199938     1.000000

# %%
default.columns
# Out:
# Index(['Income', 'Age', 'Loan', 'Loan to Income', 'Default'], dtype='object')

# %%
#3
y=default['Default']
#X=default.drop(['Default'],axis=1)
X=default[['Income', 'Age', 'Loan', 'Loan to Income']]

# %%
#4
from sklearn.model_selection import train_test_split
X_test,X_train,y_test,y_train=train_test_split(X,y,train_size=0.7,random_state=2529)

# %%
#5
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
from sklearn.ensemble import GradientBoostingClassifier
model=GradientBoostingClassifier()

# %%
#6
model.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
#7
y_pred=model.predict(X_test)

# %%
#8
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9971428571428571

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1195,    3],
#        [   1,  201]])

# %%
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00      1198\n           1       0.99      1.00      0.99       202\n\n    accuracy                           1.00      1400\n   macro avg       0.99      1.00      0.99      1400\nweighted avg       1.00      1.00      1.00      1400\n'

# %% [markdown]
# Women cloth prediction with multi nominal Naive Bayes

# %%
#1 import library

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
#2 read or import dataset
df=pd.read_csv("https://raw.githubusercontent.com/YBI-Foundation/Teaching-Data/main/Women%20Clothing%20E-Commerce%20Review.csv")

# %%
df.head()
# Out:
#    Clothing ID  Age                    Title  \
# 0          767   33                      NaN
# 1         1080   34                      NaN
# 2         1077   60  Some major design flaws
# 3         1049   50         My favorite buy!
# 4          847   47         Flattering shirt
#
#                                               Review  Rating  Recommended  \
# 0  Absolutely wonderful - silky and sexy and comf...       4            1
# 1  Love this dress!  it's sooo pretty.  i happene...       5            1
# 2  I had such high hopes for this dress and reall...       3            0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5            1
# 4  This shirt is very flattering to all due to th...       5            1
#
#    Positive Feedback        Division Department   Category
# 0                  0       Initmates   Intimate  Intimates
# 1                  4         General    Dresses    Dresses
# 2                  0         General    Dresses    Dresses
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Clothing ID        23486 non-null  int64
#  1   Age                23486 non-null  int64
#  2   Title              19676 non-null  object
#  3   Review             22641 non-null  object
#  4   Rating             23486 non-null  int64
#  5   Recommended        23486 non-null  int64
#  6   Positive Feedback  23486 non-null  int64
#  7   Division           23472 non-null  object
#  8   Department         23472 non-null  object
#  9   Category           23472 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 1.8+ MB

# %%
df.shape
# Out:
# (23486, 10)

# %% [markdown]
# remove missing values in reviews with no review text

# %%
#df.isnull().sum()
df.isna().sum()
# Out:
# Clothing ID             0
# Age                     0
# Title                3810
# Review                845
# Rating                  0
# Recommended             0
# Positive Feedback       0
# Division               14
# Department             14
# Category               14
# dtype: int64

# %%
df[df['Review']==""]=np.NaN

# %%
df['Review'].fillna("No Review",inplace=True)

# %%
df.isna().sum()
# Out:
# Clothing ID             0
# Age                     0
# Title                3810
# Review                  0
# Rating                  0
# Recommended             0
# Positive Feedback       0
# Division               14
# Department             14
# Category               14
# dtype: int64

# %%
df["Review"]
# Out:
# 0        Absolutely wonderful - silky and sexy and comf...
# 1        Love this dress!  it's sooo pretty.  i happene...
# 2        I had such high hopes for this dress and reall...
# 3        I love, love, love this jumpsuit. it's fun, fl...
# 4        This shirt is very flattering to all due to th...
#                                ...
# 23481    I was very happy to snag this dress at such a ...
# 23482    It reminds me of maternity clothes. soft, stre...
# 23483    This fit well, but the top was very see throug...
# 23484    I bought this dress for a wedding i have this ...
# 23485    This dress in a lovely platinum is feminine an...
# Name: Review, Length: 23486, dtype: object

# %%
#3 define x and y
df.columns
# Out:
# Index(['Clothing ID', 'Age', 'Title', 'Review', 'Rating', 'Recommended',
#        'Positive Feedback', 'Division', 'Department', 'Category'],
#       dtype='object')

# %%
X=df[['Review']]
y=df['Rating']

# %%
df["Rating"].value_counts()
# Out:
# 5.0    13131
# 4.0     5077
# 3.0     2871
# 2.0     1565
# 1.0      842
# Name: Rating, dtype: int64

# %%
#4 train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.7,stratify=y,random_state=2529,)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((16440, 1), (7046, 1), (16440,), (7046,))

# %% [markdown]
# get feature text conversion to tokens

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(lowercase=True,analyzer='word',ngram_range=(2,3),stop_words='english',max_features=5000)

# %%
X_train=cv.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-fd602511a6be> in <cell line: 1>()
# ----> 1 X_train=cv.fit_transform(X_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1386                     break
#    1387
# -> 1388         vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1389
#    1390         if self.binary:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1292             vocabulary = dict(vocabulary)
#    1293             if not vocabulary:
# -> 1294                 raise ValueError(
#    1295                     "empty vocabulary; perhaps the documents only contain stop words"
#    1296                 )
#
# ...

# %% [markdown]
# #hand written digit prediction

# %%
#1 import library
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
#2 import data

# %% [markdown]
# #servo prediction using linear regression

# %%
#import library
import pandas as pd
import numpy as np

# %%
#importing data
df=pd.read_csv("https://github.com/YBI-Foundation/Dataset/raw/main/Servo%20Mechanism.csv")

# %%
df.head()
# Out:
#   Motor Screw  Pgain  Vgain  Class
# 0     E     E      5      4      4
# 1     B     D      6      5     11
# 2     D     D      4      3      6
# 3     B     A      3      2     48
# 4     D     B      6      5      6

# %%
df.describe()
# Out:
#             Pgain       Vgain       Class
# count  167.000000  167.000000  167.000000
# mean     4.155689    2.538922   21.173653
# std      1.017770    1.369850   13.908038
# min      3.000000    1.000000    1.000000
# 25%      3.000000    1.000000   10.500000
# 50%      4.000000    2.000000   18.000000
# 75%      5.000000    4.000000   33.500000
# max      6.000000    5.000000   51.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Motor   167 non-null    object
#  1   Screw   167 non-null    object
#  2   Pgain   167 non-null    int64
#  3   Vgain   167 non-null    int64
#  4   Class   167 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 6.6+ KB

# %%
df.columns
# Out:
# Index(['Motor', 'Screw', 'Pgain', 'Vgain', 'Class'], dtype='object')

# %%
df.shape
# Out:
# (167, 5)

# %%
df[["Motor"]].value_counts()
# Out:
# Motor
# C        40
# A        36
# B        36
# E        33
# D        22
# dtype: int64

# %%
df[["Screw"]].value_counts()
# Out:
# Screw
# A        42
# B        35
# C        31
# D        30
# E        29
# dtype: int64

# %% [markdown]
# get encoding of  categorial value

# %%
df.replace({"Motor":{"A":0,"B":1,"C":2,"D":3,"E":4}},inplace=True)

# %%
df.replace({"Screw":{"A":0,"B":1,"C":2,"D":3,"E":4}},inplace=True)

# %%
# define x and y
y=df["Class"]
X=df[['Motor', 'Screw', 'Pgain', 'Vgain']]

# %%
y.shape
# Out:
# (167,)

# %%
y
# Out:
# 0       4
# 1      11
# 2       6
# 3      48
# 4       6
#        ..
# 162    44
# 163    40
# 164    25
# 165    44
# 166    20
# Name: Class, Length: 167, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=2529,test_size=0.3)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((116, 4), (51, 4), (116,), (51,))

# %%
#tain model
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
#fit model
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#prediction
y_pred=model.predict(X_test)

# %%
#accuraccy
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 7.190539677251235

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.8268204638174629

# %% [markdown]
# error=100-82=18

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 66.03589175595563

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6807245170563927

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel("Actual")
plt.ylabel("predicted")
plt.title("actual vs predicted")
plt.show()

# %% [markdown]
# get future prediction
#
# ```
# # This is formatted as code
# ```

# %%
X_new=df.sample(1)

# %%
X_new
# Out:
#     Motor  Screw  Pgain  Vgain  Class
# 54      1      1      4      2     18

# %%
X_new.shape
# Out:
# (1, 5)

# %%
X_new=X_new.drop("Class",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-01cda36029cd> in <cell line: 1>()
# ----> 1 X_new=X_new.drop("Class",axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
y_pred_new = model.predict(X_new)

# %%
y_pred_new
# Out:
# array([25.06611589])
